# %%
import sys
from PIL import Image
sys.path.append("..")
sys.path.append("../src")
sys.path.append("../utils")

from src.utils import *

# %%
labels = [("DART_sart", "c" ), ("DART_sirt", "g"), ("SART", "r"), ("SIRT", "m")]
tick_labels = [0., 0.25, 0.5, 0.85, 1.]

parent_path = '../results/p_fix_50proj_180ar/'

# %%
res_path = f"{parent_path}paws/"
title="Effect of fix probability on Paw phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
# save_name= "../plots_for_report/poisson_clouds.png"
save_name = None
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=3, save_name=save_name)
# Out:
# Considered subdirectories: ['paw_0.png', 'paw_1.png', 'paw_2.png']

# %%
res_path = f"{parent_path}clouds/"
title="Effect of fix probability on Cloud phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
# save_name= "../plots_for_report/poisson_clouds.png"
save_name = None
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=1, save_name=save_name)
# Out:
# Considered subdirectories: ['cloud_0.png', 'cloud_1.png', 'cloud_2.png']

# %%
res_path = f"{parent_path}semilunars/"
title="Effect of fix probability on Semilunar phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
# save_name= "../plots_for_report/poisson_clouds.png"
save_name = None
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=3, save_name=save_name)
# Out:
# Considered subdirectories: ['semilunar_0.png', 'semilunar_1.png', 'semilunar_2.png']

# %%
res_path = f"{parent_path}aliens/"
title="Effect of fix probability on Alien phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
# save_name= "../plots_for_report/poisson_clouds.png"
save_name = None
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=0.8, save_name=save_name)
# Out:
# Considered subdirectories: ['alien_0.png', 'alien_1.png', 'alien_2.png']
