# %%
import numpy as np
from os import listdir, makedirs
from os.path import exists
import matplotlib.pyplot as plt
from PIL import Image
import sys
sys.path.append("..")
sys.path.append("../src")
from src.utils import *

plt.style.use('seaborn-whitegrid')

# %%
labels = [("DART_sart", "c" ), ("DART_sirt", "g"), ("SART", "r"), ("SIRT", "m"), ("DART_fbp", "b"), ("RBF", "y")]
tick_labels = [10, 20, 30, 40, 50, 60, 80, 100, 120, 150, 180]
figs_size = (7,5)
#tick_labels = np.round([(label/53418)*100 for label in tick_labels],1)
parent_path = '../results/angle_range/'
save_dir = "../report_plots/"

# %%
res_path = f"{parent_path}clouds"
title="Effect of angle range on Cloud phantoms"
xlabel="Angle range"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name = f"{save_dir}ang_clouds.png"

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size= figs_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=50, save_name=save_name)
# Out:
# Considered subdirectories: ['cloud_0.png', 'cloud_1.png', 'cloud_2.png']

# %%
res_path = f"{parent_path}paws"
title="Effect of angle range on Paw phantoms"
xlabel="Angle range"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name = f"{save_dir}ang_paws.png"
# save_name = None

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=figs_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=50, save_name=save_name)
# Out:
# Considered subdirectories: ['paw_0.png', 'paw_1.png', 'paw_2.png']

# %%
res_path = f"{parent_path}semilunars"
title="Effect of angle range on Semilunar phantoms"
xlabel="Angle range"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name= f"{save_dir}ang_semilunars.png"
# save_name = None

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=figs_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=50, save_name=save_name)
# Out:
# Considered subdirectories: ['semilunar_0.png', 'semilunar_1.png', 'semilunar_2.png']

# %%
res_path = f"{parent_path}aliens"
title="Effect of angle range on Alien phantoms"
xlabel="Angle range"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name= f"{save_dir}ang_aliens.png"
# save_name = None

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=figs_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=15, save_name=save_name)
# Out:
# Considered subdirectories: ['alien_0.png', 'alien_1.png', 'alien_2.png']

# %%
aliens = np.array(Image.open(f"{save_dir}ang_aliens.png"))
clouds = np.array(Image.open(f"{save_dir}ang_clouds.png"))
paws = np.array(Image.open(f"{save_dir}ang_paws.png"))
semilunars = np.array(Image.open(f"{save_dir}ang_semilunars.png"))

fig, ax = plt.subplots(2,2,figsize=(12,12))


ax[0,0].imshow(clouds)
ax[0,0].set_axis_off()

ax[0,1].imshow(paws)
ax[0,1].set_axis_off()

ax[1,0].imshow(aliens)
ax[1,0].set_axis_off()

ax[1,1].imshow(semilunars)
ax[1,1].set_axis_off()

plt.subplots_adjust(wspace=-0.05, hspace=-0.35)
