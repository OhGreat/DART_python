# %%
import sys
from PIL import Image
sys.path.append("..")
sys.path.append("../src")
sys.path.append("../utils")
from src.utils import *

plt.style.use('seaborn-whitegrid')
fig_size=(7,5)

# %%
labels = [("DART_sart", "c" ), ("DART_sirt", "g"), ("SART", "r"), ("SIRT", "m"), ("DART_fbp", "b"), ("RBF", "y")]
tick_labels = [ 0, 1500, 3000, 4500, 6000, 7500, 9000]
tick_labels = [str(np.round((noise/53418)*100, 1))+"%" for noise in tick_labels]

# %%
res_path = "../results/noise_exps/clouds"
title="Effect of Poisson noise on Cloud phantoms"
xlabel="Poisson noise %"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name= "../plots_for_report/poisson_clouds.png"
# save_name = None
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=20, save_name=save_name)
# Out:
# Considered subdirectories: ['cloud_0.png', 'cloud_1.png', 'cloud_2.png']

# %%
res_path = "../results/noise_exps/paws"
title="Effect of Poisson noise on Paw phantoms"
xlabel="Poisson noise %"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name= "../plots_for_report/poisson_paws.png"

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=20, save_name=save_name)
# Out:
# Considered subdirectories: ['paw_0.png', 'paw_1.png', 'paw_2.png']

# %%
res_path = "../results/noise_exps/semilunars"
title="Effect of Poisson noise on Semilunar phantoms"
xlabel="Poisson noise %"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name= "../plots_for_report/poisson_semilunars.png"

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=20, save_name=save_name)
# Out:
# Considered subdirectories: ['semilunar_0.png', 'semilunar_1.png', 'semilunar_2.png']

# %%
res_path = "../results/noise_exps/aliens"
title="Effect of Poisson noise on Alien phantoms"
xlabel="Poisson noise %"
ylabel="Mean Absolute Pixel Error"
ylim=50
save_name= "../plots_for_report/poisson_aliens.png"

plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=20, save_name=save_name)
# Out:
# Considered subdirectories: ['alien_0.png', 'alien_1.png', 'alien_2.png']

# %%
aliens = np.array(Image.open("../plots_for_report/poisson_aliens.png"))
clouds = np.array(Image.open("../plots_for_report/poisson_clouds.png"))
paws = np.array(Image.open("../plots_for_report/poisson_paws.png"))
semilunars = np.array(Image.open("../plots_for_report/poisson_semilunars.png"))

fig, ax = plt.subplots(2,2,figsize=(12,12))


ax[0,0].imshow(clouds)
ax[0,0].set_axis_off()

ax[0,1].imshow(paws)
ax[0,1].set_axis_off()

ax[1,0].imshow(aliens)
ax[1,0].set_axis_off()

ax[1,1].imshow(semilunars)
ax[1,1].set_axis_off()

plt.subplots_adjust(wspace=-0.05, hspace=-0.35)
