# %%
import sys
from PIL import Image
sys.path.append("..")
sys.path.append("../src")
sys.path.append("../utils")
from src.utils import *

plt.style.use('seaborn-whitegrid')
fig_size=(7,5)

# %%
labels = [("DART_sart", "c" ), ("DART_sirt", "g"), ("SART", "r"), ("SIRT", "m")]

tick_labels = [0., 0.25, 0.5, 0.85, 1.]
colors = ['c', 'g', 'r', 'm']
parent_path = '../results/p_fix_10proj_120ar/'
save_path = '../plots_for_report/'

# %%
res_path = f"{parent_path}paws/"
title="Effect of fix probability on Paw phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
save_name= f"{save_path}p_fixed_10_proj_paws.png"
# save_name = None
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=8, save_name=save_name)
# Out:
# Considered subdirectories: ['paw_0.png', 'paw_1.png', 'paw_2.png']

# %%
res_path = f"{parent_path}clouds/"
title="Effect of fix probability on Cloud phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
save_name= "../plots_for_report/p_fixed_10_proj_clouds.png"
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=3, save_name=save_name)
# Out:
# Considered subdirectories: ['cloud_0.png', 'cloud_1.png', 'cloud_2.png']

# %%
res_path = f"{parent_path}semilunars/"
title="Effect of fix probability on Semilunar phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
save_name= "../plots_for_report/p_fixed_10_proj_semilunars.png"
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=7, save_name=save_name)
# Out:
# Considered subdirectories: ['semilunar_0.png', 'semilunar_1.png', 'semilunar_2.png']

# %%
res_path = f"{parent_path}aliens/"
title="Effect of fix probability on Alien phantoms"
xlabel="fix probability"
ylabel="Mean Absolute Pixel Error"
ylim=10
save_name= "../plots_for_report/p_fixed_10_proj_aliens.png"
plot_results(res_dir=res_path, labels=labels,
            tick_labels=tick_labels, fig_size=fig_size,
            title=title, xlabel=xlabel, ylabel=ylabel,
            ylim=2.5, save_name=save_name)
# Out:
# Considered subdirectories: ['alien_0.png', 'alien_1.png', 'alien_2.png']

# %%
paws = np.array(Image.open("../plots_for_report/p_fixed_10_proj_paws.png"))
clouds = np.array(Image.open("../plots_for_report/p_fixed_10_proj_clouds.png"))
semilunars = np.array(Image.open("../plots_for_report/p_fixed_10_proj_semilunars.png"))
aliens = np.array(Image.open("../plots_for_report/p_fixed_10_proj_aliens.png"))

fig, ax = plt.subplots(2,2,figsize=(12,12))


ax[0,0].imshow(clouds)
ax[0,0].set_axis_off()

ax[0,1].imshow(paws)
ax[0,1].set_axis_off()

ax[1,0].imshow(aliens)
ax[1,0].set_axis_off()

ax[1,1].imshow(semilunars)
ax[1,1].set_axis_off()

plt.subplots_adjust(wspace=-0.05, hspace=-0.35)
